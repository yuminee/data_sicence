# %%
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('data/body.csv', index_col = 0)
body_df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
body_df.plot(kind='scatter', x = 'Height', y ='Weight')

# %%
sns.lmplot(data=body_df, x = 'Height', y = 'Weight')

# %%
#회귀선이 생긴다. 흩어져있는선들을 하나의 선으로 표현하기위헤 나름의 최선을 다함
